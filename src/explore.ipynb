# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd
from sklearn.model_selection import train_test_split

X_train = pd.read_csv('https://raw.githubusercontent.com/Nicolas-DL/arbol_decision/refs/heads/main/data/processed/X_train.csv')
X_test = pd.read_csv('https://raw.githubusercontent.com/Nicolas-DL/arbol_decision/refs/heads/main/data/processed/X_test.csv')
y_train = pd.read_csv('https://raw.githubusercontent.com/Nicolas-DL/arbol_decision/refs/heads/main/data/processed/y_train.csv')
y_test = pd.read_csv('https://raw.githubusercontent.com/Nicolas-DL/arbol_decision/refs/heads/main/data/processed/y_test.csv')

X_train.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose   BMI  DiabetesPedigreeFunction   Age
# 0           0          2.0     84.0   0.0                     0.304  21.0
# 1           1          9.0    112.0  28.2                     1.282  50.0
# 2           2          1.0    139.0  28.7                     0.654  22.0
# 3           3          0.0    161.0  21.9                     0.254  65.0
# 4           4          6.0    134.0  46.2                     0.238  46.0

# %%
dataframes = [X_train, X_test, y_train, y_test]

for df in dataframes:
    if 'Unnamed: 0' in df.columns:
        df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
from xgboost import XGBClassifier
from sklearn.base import ClassifierMixin

class XGBClassifier(XGBClassifier, ClassifierMixin):
    pass

# %%
from xgboost import XGBClassifier

model = XGBClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
# ...

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
print(f'accuracy score = {accuracy_score(y_pred, y_test)}')
# Out:
# accuracy score = 0.7597402597402597

# %%
from sklearn.model_selection import GridSearchCV

grid = {
    'n_estimators':[50, 100, 200],
    'learning_rate':[0.001, 0.01, 0.1, 0.5]
}

grid_search = GridSearchCV(model, grid, scoring='accuracy', cv=5)

grid_search.fit(X_train, y_train)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/_tags.py:354: FutureWarning: The XGBClassifier or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       3 grid = {
#       4     'n_estimators':[50, 100, 200],
#       5     'learning_rate':[0.001, 0.01, 0.1, 0.5]
#       6 }
#       8 grid_search = GridSearchCV(model, grid, scoring='accuracy', cv=5)
# ---> 10 grid_search.fit(X_train, y_train)
#
# ...

# %% [markdown]
# *No funciona correctamente XGBoost, a pesar de haber actualizado la versión de sklearn. Por lo mismo, utilizaré boosting de la bilbioteca sklearn y mejoraré los hiperparámetros del ese modelo*

# %%
from sklearn.ensemble import GradientBoostingClassifier

model2 = GradientBoostingClassifier(n_estimators = 5, random_state = 42)

model2.fit(X_train, y_train)

y_pred2 = model2.predict(X_test)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(f'accuracy score = {accuracy_score(y_pred2, y_test)}')
# Out:
# accuracy score = 0.7272727272727273

# %%
from sklearn.model_selection import GridSearchCV

grid2 = {
    'n_estimators':[10, 20, 30, 40, 50, 100, 200, 250],
    'learning_rate':[0.001, 0.01, 0.1, 0.5]
}

grid_search2 = GridSearchCV(model2, grid2, scoring='accuracy', cv=5)

grid_search2.fit(X_train, y_train)
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
best_model = grid_search2.best_estimator_
grid_search2.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 200}

# %%
y_best_pred = best_model.predict(X_test)

# %%
print(f'accuracy score = {accuracy_score(y_best_pred, y_test)}')
# Out:
# accuracy score = 0.7142857142857143

# %% [markdown]
# *No mejoró el accuracy_score con la modificación de hiperparametros. Los modelos de los proyectos anteriores me dieron mejores resultados(decision_tree accuracy = 0.78, random_forest accuracy = 0.78). Dejaré guardado el modelo de boosting hecho con XGBClassifier de la biblioteca xgboost para este proyecto*

# %%
from pickle import dump

dump(model, open("../models/boosting_model.sav", "wb"))
